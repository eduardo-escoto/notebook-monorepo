# %% [markdown]
# # Test notebook!

# %% [markdown]
# ## this is a notebook to test my jupyter renderer
# **lets see how this works** *?????*

# %% [markdown]
# This is a math cell, COOOOL
# $$
# f(x) = \begin{cases}
#       0 & x\leq 0 \\
#       \frac{100-x}{100} & 0\leq x\leq 100 \\
#       0 & 100\leq x
#    \end{cases}
# $$
#
# And also with inline math $6+9=69$

# %%
# this code has comments
import numpy as np
import pandas as pd

# %%
# this code has error!!
assert 1 == 2
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/l8/8wglb79d283gd8d84s0tpb_r0000gn/T/ipykernel_5342/1496019761.py in <module>
#       1 # this code has error!!
# ----> 2 assert 1 == 2
#
# AssertionError:

# %%
# this code has a dataframe 
data = pd.DataFrame({"test1": np.random.uniform(size = 45), "test2": np.linspace(0,0.45,45)})
data
# Out:
#        test1     test2
# 0   0.946945  0.000000
# 1   0.192436  0.010227
# 2   0.608871  0.020455
# 3   0.049355  0.030682
# 4   0.787643  0.040909
# 5   0.500934  0.051136
# 6   0.391572  0.061364
# 7   0.014672  0.071591
# 8   0.626618  0.081818
# 9   0.487658  0.092045
# 10  0.015356  0.102273
# 11  0.083126  0.112500
# 12  0.325302  0.122727
# 13  0.857529  0.132955
# 14  0.873374  0.143182
# 15  0.478283  0.153409
# 16  0.941958  0.163636
# 17  0.132511  0.173864
# 18  0.660969  0.184091
# 19  0.396600  0.194318
# 20  0.790107  0.204545
# 21  0.776167  0.214773
# 22  0.908258  0.225000
# 23  0.658169  0.235227
# 24  0.294046  0.245455
# 25  0.153415  0.255682
# 26  0.677221  0.265909
# 27  0.376840  0.276136
# 28  0.083102  0.286364
# 29  0.515438  0.296591
# 30  0.905440  0.306818
# 31  0.149857  0.317045
# 32  0.191390  0.327273
# 33  0.418096  0.337500
# 34  0.272064  0.347727
# 35  0.436765  0.357955
# 36  0.277824  0.368182
# 37  0.449809  0.378409
# 38  0.437757  0.388636
# ...

# %%
# this code has a plot
import matplotlib.pyplot as plt
plt.scatter(data['test1'], data['test2'])

# %%
# this code has a dataframe 
data = pd.DataFrame({"test1": np.random.uniform(size = 45), "test2": np.linspace(0,0.45,45)})


# this code has a plot
import matplotlib.pyplot as plt
plt.scatter(data['test1'], data['test2'])
plt.show()
data
# Out:
#        test1     test2
# 0   0.299001  0.000000
# 1   0.147353  0.010227
# 2   0.288408  0.020455
# 3   0.841900  0.030682
# 4   0.398316  0.040909
# 5   0.637695  0.051136
# 6   0.778574  0.061364
# 7   0.013727  0.071591
# 8   0.210379  0.081818
# 9   0.724688  0.092045
# 10  0.633269  0.102273
# 11  0.032368  0.112500
# 12  0.115497  0.122727
# 13  0.206166  0.132955
# 14  0.406377  0.143182
# 15  0.828367  0.153409
# 16  0.128659  0.163636
# 17  0.861360  0.173864
# 18  0.524153  0.184091
# 19  0.074675  0.194318
# 20  0.602478  0.204545
# 21  0.288823  0.214773
# 22  0.654822  0.225000
# 23  0.577426  0.235227
# 24  0.554136  0.245455
# 25  0.417491  0.255682
# 26  0.448069  0.265909
# 27  0.498289  0.276136
# 28  0.767953  0.286364
# 29  0.768841  0.296591
# 30  0.498709  0.306818
# 31  0.331756  0.317045
# 32  0.511546  0.327273
# 33  0.369192  0.337500
# 34  0.964109  0.347727
# 35  0.961238  0.357955
# 36  0.336033  0.368182
# 37  0.631474  0.378409
# 38  0.924052  0.388636
# ...

# %%
# this code has a dataframe 
data = pd.DataFrame({"test1": np.random.uniform(size = 45), "test2": np.linspace(0,0.45,45)})


# this code has a plot
import matplotlib.pyplot as plt
print(data)
plt.scatter(data['test1'], data['test2'])
# Out:
#        test1     test2
# 0   0.724083  0.000000
# 1   0.366593  0.010227
# 2   0.089890  0.020455
# 3   0.706547  0.030682
# 4   0.999692  0.040909
# 5   0.709339  0.051136
# 6   0.787896  0.061364
# 7   0.185219  0.071591
# 8   0.967197  0.081818
# 9   0.105714  0.092045
# 10  0.306608  0.102273
# 11  0.173774  0.112500
# 12  0.308866  0.122727
# 13  0.644464  0.132955
# 14  0.264283  0.143182
# 15  0.255175  0.153409
# 16  0.467236  0.163636
# 17  0.792861  0.173864
# 18  0.056477  0.184091
# 19  0.178081  0.194318
# 20  0.969675  0.204545
# 21  0.148732  0.214773
# 22  0.589673  0.225000
# 23  0.040219  0.235227
# 24  0.205726  0.245455
# 25  0.281048  0.255682
# 26  0.517904  0.265909
# 27  0.564034  0.276136
# 28  0.429875  0.286364
# 29  0.157420  0.296591
# 30  0.585274  0.306818
# 31  0.780701  0.317045
# 32  0.854081  0.327273
# 33  0.354421  0.337500
# 34  0.660860  0.347727
# 35  0.341265  0.357955
# 36  0.436896  0.368182
# 37  0.231335  0.378409
# 38  0.411911  0.388636
# ...
